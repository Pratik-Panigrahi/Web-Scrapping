# %%
# !pip install selenium

# %% [markdown]
# # Scrapping Jeans Images

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import urllib.request
import requests
browser=webdriver.Chrome("C:\chrome driver\chromedriver.exe")
browser.get('https://www.amazon.in/s?i=apparel&bbn=1968076031&rh=n%3A1571271031%2Cn%3A1571272031%2Cn%3A1968024031%2Cn%3A1968076031%2Cp_n_size_two_browse-vebin%3A1975328031%2Cp_n_style_browse-bin%3A1975055031&dc&fst=as%3Aoff&qid=1593587052&rnid=1975040031&ref=sr_nr_p_n_style_browse-bin_3')
# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=30):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(200,300)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/71xj3e4ulHL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81Z2ZutboVL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71JP24A1VWL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81lHV9GG+SL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81x7fYj9I2L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81m1zGBLTDL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71nHOd28QvL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61SNoeNUTlL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71QMVd+dr4L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81re1UZMfmL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71jj9e0Rt8L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91wN1O7R8lL._AC_UL320_.jpg
# loop break
# ...

# %% [markdown]
# # Scrapping saree Images

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import urllib.request
import requests
browser=webdriver.Chrome("C:\chrome driver\chromedriver.exe")
browser.get('https://www.amazon.in/s?i=apparel&bbn=1968256031&rh=n%3A1571271031%2Cn%3A1571272031%2Cn%3A1953602031%2Cn%3A1968253031%2Cn%3A1968256031%2Cp_n_size_two_browse-vebin%3A1975321031%7C1975326031%2Cp_n_material_browse%3A5836978031&s=popularity-rank&lo=image&dc&pf_rd_i=1953602031&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_p=e1d7771a-d127-43ba-9fa6-cdc05a7a5f80&pf_rd_r=RS10HF770TV4Y22BCVFW&pf_rd_s=merchandised-search-8&qid=1593589094&rnid=1974774031&ref=sr_nr_p_n_material_browse_4')
# soup=BeautifulSoup(browser.page_source)
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=30):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(150,200)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/71bqVV8r0gL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71TQPd1gaiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91NtqE1gRrL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61BqWbpWmtL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61q0P4DolXL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71DG++7RwrL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71K-I+reZwL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/91BzcOSLctL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71kcf9OG3QL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71lMg8Gll-L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71EyReGVFqL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81stJls55TL._AC_UL320_.jpg
# loop break
# ...

# %% [markdown]
# # Scrapping Trousers Images

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import random
import urllib.request
import requests
browser=webdriver.Chrome("C:\chrome driver\chromedriver.exe")
browser.get('https://www.amazon.in/s?k=trousers&i=apparel&bbn=1968125031&rh=n%3A1968125031%2Cp_n_material_browse%3A1974789031&dc&qid=1593591138&rnid=1974774031&ref=sr_nr_p_n_material_browse_5')
# soup=BeautifulSoup(browser.page_source
html = browser.page_source
soup = BeautifulSoup(html)


#do something useful
#prints all the links with corresponding text
all_images = []
for link in soup.find_all('div',{"data-component-type":"s-search-result"},limit=30):
    href = link.img['src']
    print(href)
    
    img_name = random.randrange(251,300)
    
    full_name = str(img_name) + ".jpg"
    
    urllib.request.urlretrieve(href, full_name)
    
    print("loop break")
       
# .get('src'),link.get_text()
# Out:
# https://m.media-amazon.com/images/I/81teKjNigbL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81AUG2aplKL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51D2tMRUdOL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61c2hXw3XLL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51GonaPPqUL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71KyRN8G5eL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61+OpJ2qzhL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81JBFKkhiOL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/81FwmwNm1SL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/51fDLFvapiL._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/61yr6YcH74L._AC_UL320_.jpg
# loop break
# https://m.media-amazon.com/images/I/71FOKhA09BL._AC_UL320_.jpg
# loop break
# ...
